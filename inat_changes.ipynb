# %%
import pandas as pd
from datetime import date
import re
pd.set_option('display.max_columns', None) #настройка, чтобы видеть все колонки

# %%
observations_path = 'data/observations-298709.csv'
start_date = date(2022,9,1)
# start_date = 'min'
finish_date = date(2022,11,30)
# finish_date = 'max'
# show_positions = 20
show_positions = 'all'
project_id = 'tsyurupy-i-ego-lesa'

# %%
df_full = pd.read_csv(observations_path) #создаём новый огромный датафрейм из csv
df = df_full[['id','user_login','created_at','quality_grade','scientific_name','common_name']].copy() #создаём новый маленький датафрейм с нужными столбцами
del(df_full)
# df['created_at'] = pd.to_datetime(df['created_at']).dt.date #конвертируем столбец с датами наблюдений в тип datatime
# start_date = min(df['created_at']) if start_date == 'min' else start_date
# finish_date = max(df['created_at']) if finish_date == 'max' else finish_date

# return df, start_date, finish_date

# %%
df
# Out:
#              id     user_login                 created_at quality_grade  \
# 0      16876317      entomokot  2018-09-24 14:04:37 -0400      needs_id
# 1      16876320      entomokot  2018-09-24 14:04:38 -0400      needs_id
# 2      25788653       bio_4you  2019-05-26 01:27:29 -0400      needs_id
# 3      25928353       bio_4you  2019-05-28 01:48:37 -0400      research
# 4      25928360       bio_4you  2019-05-28 01:49:18 -0400      research
# ...         ...            ...                        ...           ...
# 998   149132796  budetinetakoe  2023-02-19 09:20:33 -0500      needs_id
# 999   149133014  budetinetakoe  2023-02-19 09:23:51 -0500      needs_id
# 1000  149140704  budetinetakoe  2023-02-19 10:59:02 -0500      needs_id
# 1001  149141274  budetinetakoe  2023-02-19 11:07:15 -0500      needs_id
# 1002  149142499  budetinetakoe  2023-02-19 11:21:41 -0500      needs_id
#
#             scientific_name            common_name
# 0                 Distantes        Сморчок высокий
# 1         Attulus floricola                    NaN
# 2               Malachiinae                Малашки
# 3           Alnus glutinosa           Ольха чёрная
# 4       Veronica chamaedrys     Вероника дубравная
# ...                     ...                    ...
# 998         Cirsium vulgare     Бодяк обыкновенный
# 999                 Stereum                Стереум
# 1000  Laetiporus sulphureus  Трутовик серно-жёлтый
# 1001            Chlorophyta      Зелёные водоросли
# 1002               Cervidae               Оленевые
#
# [1003 rows x 6 columns]

# %%
def prepare_df(observations_path, start_date, finish_date):
    
    df_full = pd.read_csv(observations_path) #создаём новый огромный датафрейм из csv
    df = df_full[['id','user_login','created_at','quality_grade','scientific_name','common_name']].copy() #создаём новый маленький датафрейм с нужными столбцами
    del(df_full)
    df['created_at'] = pd.to_datetime(df['created_at'], utc=True).dt.date #конвертируем столбец с датами наблюдений в тип datatime
    start_date = min(df['created_at']) if start_date == 'min' else start_date
    finish_date = max(df['created_at']) if finish_date == 'max' else finish_date

    return df, start_date, finish_date

# %%
def prepare_to_date(df, date_to):

    #prepare_to_date нужна чтобы создать список "лучших" 
    #наблюдателей с большим количеством наблюдений на определённую дату
    

    stat = pd.DataFrame()                                                               #создаём новый датафрейм
    counts = df[df['created_at']<=date_to].loc[:,'user_login'].value_counts()           #подсчитываем количество всех наблюдений у каждого пользователя с датой предшествующей или равной date_to
    stat['user'] = counts.index                                                         #создаём колонку с именами пользователей
    stat['obs_count'] = counts.to_list()                                                #создаём колонку с кол-вом всех наблюдений
    research = df[(df['quality_grade']=='research')&(df['created_at']<=date_to)].loc[:,'user_login'].value_counts()         #подсчитываем кол-во наблюдений со статусом research у каждого пользователя
    del(df)
    stat = stat.join(research,on='user', how='left')                                    #создаём колонку с кол-вом наблюдений research, объединяя список всех наблюдений со списком наблюдений research
    del(research)
    stat.rename(columns={'user':'user',                                                 #просто нужно переименовать один столбец из-за особенности join
                        'obs_count':'obs_count',
                        'user_login':'obs_res_count'},
                         inplace=True)
    stat.fillna(0,inplace=True)                                                         #заполняем нулями значения NaN (для тех у кого нет ни одного research)
    stat['obs_res_count'] = stat['obs_res_count'].astype('Int64')                       #меняем "х.0" на "x"
    stat.sort_values(by=['obs_count','obs_res_count','user'],ascending=False,inplace=True)
    stat.insert(1,'position','')
    stat.insert(2,'pos_cool','')
    stat['position'] = range(1,counts.shape[0]+1)                                       #создаём колонку с позицией, взяв кол-во пользователей из shape
    stat['pos_cool'] = stat[['obs_count','obs_res_count']].ne(stat[['obs_count','obs_res_count']].shift()).any(axis=1).cumsum()
    
    return stat

# %%
def shiftpos(shiftrow):
    
    if shiftrow['position_y'] == 0:
        cell = '+new'
    elif shiftrow['pos_cool_shift'] > 0:
        cell = '+' + str(shiftrow['pos_cool_shift'])
    else: cell = ''

    return cell

def shiftplus(shift):

    cell = ('+' + str(shift)) if shift > 0 else ''

    return cell

# %%
def prepare_changes(df, start_date, finish_date):
    
    
    start_obs = prepare_to_date(df, start_date)
    finish_obs = prepare_to_date(df, finish_date)
    stat = finish_obs.merge(right=start_obs,how='left',left_on='user', right_on='user')   
    stat_changes = pd.DataFrame()
    stat_changes['position'] = stat['position_x']
    stat_changes['position_y'] = stat['position_y']
    stat_changes['pos_cool'] = stat['pos_cool_x']
    stat_changes['pos_cool_shift'] = stat['pos_cool_y'] - stat['pos_cool_x']
    stat_changes['user'] = stat['user']
    stat_changes['obs_count'] = stat['obs_count_x']
    stat_changes['obs_count_shift'] = stat['obs_count_x'] - stat['obs_count_y']
    stat_changes['obs_res_count'] = stat['obs_res_count_x']
    stat_changes['obs_res_count_shift'] = stat['obs_res_count_x'] - stat['obs_res_count_y'] 
    stat_changes.fillna(0,inplace=True)  
    stat_changes['pos_cool_shift'] = stat_changes['pos_cool_shift'].astype('Int64')                       #меняем "х.0" на "x"    
    stat_changes['obs_count_shift'] = stat_changes['obs_count_shift'].astype('Int64')                       #меняем "х.0" на "x"     
    stat_changes['obs_res_count_shift'] = stat_changes['obs_res_count_shift'].astype('Int64')                       #меняем "х.0" на "x"     
    stat_changes['pos_cool_shift'] = stat_changes.apply(shiftpos,axis=1)
    stat_changes['obs_count_shift'] = stat_changes['obs_count_shift'].apply(shiftplus)
    stat_changes['obs_res_count_shift'] = stat_changes['obs_res_count_shift'].apply(shiftplus)

    last_obs = df.groupby(by='user_login')['created_at'].max()
    last_obs.name = 'last_obs'
    stat_changes = stat_changes.merge(right=last_obs, left_on='user', right_index=True)

    stat_changes.sort_values(by=['obs_count','obs_res_count','user'],ascending=False,inplace=True)

    return stat_changes

# %%
def changes_linking(row):

    user_id = row['user']
    
    obs_count = row['obs_count']
    obs_count_shift = row['obs_count_shift']
    obs_res_count = row['obs_res_count']
    obs_res_count_shift = row['obs_res_count_shift']
    pos_cool = row['pos_cool']

    row['obs_count'] = f'<a href="https://www.inaturalist.org/observations?created_d2={finish_date}&place_id=any&project_id={project_id}&subview=map&user_id={user_id}&verifiable=True" style="color:black">{obs_count}</a>&nbsp;&nbsp;'
    row['obs_count_shift'] = f'<a href="https://www.inaturalist.org/observations?created_d1={start_date}&created_d2={finish_date}&place_id=any&project_id={project_id}&subview=map&user_id={user_id}&verifiable=True" style="color:black">{obs_count_shift}</a>'
    row['obs_res_count'] = f'<a href="https://www.inaturalist.org/observations?created_d2={finish_date}&place_id=any&project_id={project_id}&subview=map&user_id={user_id}&verifiable=True&quality_grade=research" style="color:black">{obs_res_count}</a>&nbsp;&nbsp;'
    row['obs_res_count_shift'] = f'<a href="https://www.inaturalist.org/observations?created_d1={start_date}&created_d2={finish_date}&place_id=any&project_id={project_id}&subview=map&user_id={user_id}&verifiable=True&quality_grade=research" style="color:black">{obs_res_count_shift}</a>&nbsp;&nbsp;'

    row['user'] = f'<span color:black">@{user_id}</span>'
    # row['pos_cool'] = f'&nbsp;{pos_cool}'

    return row

# %%
def changes_beauty(changes, show_positions):
    if show_positions == 'all':
        show_positions = changes.shape[0] - 1
    changes = changes[((changes['pos_cool'] == (show_positions+1)).cumsum() != 1)].copy()
    changes['pos_cool'] = changes['pos_cool'].astype(str) + changes['pos_cool_shift']
    changes['obs_count'] = changes['obs_count'].astype(str) + changes['obs_count_shift']
    changes['obs_res_count'] = changes['obs_res_count'].astype(str) + changes['obs_res_count_shift']
    changes.drop(['position','position_y','pos_cool_shift','obs_res_count_shift','obs_count_shift'], axis=1, inplace=True)
    changes['last_obs'] = changes['last_obs'].apply(format_last_obs)
    changes.columns = ['#','Кто','Наблюдения','Наблюдения,<br>    исследовательский уровень','Последнее наблюдение']

    return changes

# last_obs = changes['last_obs'].iloc[0]

def format_last_obs(last_obs):
    
    year, month, day = str(last_obs).split('-')

    spring = range(3,6)
    summer = range(6,9)
    autumn = range(9,12)

    month = int(month)

    if month in spring:
        season = 'весна'
    elif month in summer:
        season = 'лето'
    elif month in autumn:
        season = 'осень'
    else:
        season = 'зима'

    last_obs = season + "'" + year[-2:]
    
    return last_obs

# %%
def changes_html(changes):
  
  changes.to_html('output/changes.html', header=True, index=False, escape=False, justify='left', border=None)

  with open('output/changes.html', 'r') as file :
    filedata = file.read()

  filedata = filedata.replace(' class="dataframe"', '') # Replace the target string
  filedata = filedata.replace('<th>', '<th  style="vertical-align:top">')
  filedata = filedata.replace('+new', '&nbsp;<b style="font-size:62%;color:green">NEW</b>')
  filedata = re.sub('\+([0-9]+)',r'<b style="font-size:62%;color:green">&#8593;\1</b>',filedata)

  with open('output/changes.html', 'w') as file: # Write the file out again
    file.write(filedata)

# %%
obs, start_date, finish_date = prepare_df(observations_path, start_date, finish_date)
print(start_date, finish_date)
obs
# Out:
# 2022-09-01 2022-11-30
#              id     user_login  created_at quality_grade  \
# 0      16876317      entomokot  2018-09-24      needs_id
# 1      16876320      entomokot  2018-09-24      needs_id
# 2      25788653       bio_4you  2019-05-26      needs_id
# 3      25928353       bio_4you  2019-05-28      research
# 4      25928360       bio_4you  2019-05-28      research
# ...         ...            ...         ...           ...
# 998   149132796  budetinetakoe  2023-02-19      needs_id
# 999   149133014  budetinetakoe  2023-02-19      needs_id
# 1000  149140704  budetinetakoe  2023-02-19      needs_id
# 1001  149141274  budetinetakoe  2023-02-19      needs_id
# 1002  149142499  budetinetakoe  2023-02-19      needs_id
#
#             scientific_name            common_name
# 0                 Distantes        Сморчок высокий
# 1         Attulus floricola                    NaN
# 2               Malachiinae                Малашки
# 3           Alnus glutinosa           Ольха чёрная
# 4       Veronica chamaedrys     Вероника дубравная
# ...                     ...                    ...
# 998         Cirsium vulgare     Бодяк обыкновенный
# 999                 Stereum                Стереум
# 1000  Laetiporus sulphureus  Трутовик серно-жёлтый
# 1001            Chlorophyta      Зелёные водоросли
# 1002               Cervidae               Оленевые
#
# [1003 rows x 6 columns]

# %%
changes = prepare_changes(obs, start_date, finish_date)
changes
# Out:
#     position  position_y  pos_cool pos_cool_shift                 user  \
# 0          1        27.0         1            +19        budetinetakoe
# 1          2         0.0         2           +new  anastasiiamerkulova
# 2          3         1.0         3                        elenasuslova
# 3          4         2.0         4                    mitrula_paludosa
# 4          5         3.0         5                      daria_kalinina
# 5          6         4.0         6                              taimyr
# 6          7         5.0         7                      kirill_kuptsov
# 7          8         6.0         8                            bio_4you
# 8          9         7.0         9                 elizaveta_boldinova
# 9         10         8.0        10                     naturalist40722
# 10        11         9.0        11                               wuce6
# 11        12        10.0        12                               lande
# 12        13         0.0        13           +new        infifororient
# 13        14        19.0        14             +4             forestru
# 14        15        11.0        15                        yu_postnikov
# 15        16        12.0        16                           lachinova
# 16        17        13.0        17                              irened
# 17        18        14.0        18                        ivan_savinov
# 18        19        15.0        19                             elfenok
# 19        20        16.0        20                           anatoly_m
# 20        21        17.0        21                         oxanasayuri
# 21        22        18.0        22                     naturalist14616
# 22        23        20.0        22                             datakuz
# 23        24        21.0        23                           entomokot
# 24        25        22.0        24                     naturalist35009
# 25        26        23.0        24                     naturalist33527
# 26        27        24.0        24                     naturalist11373
# 27        28        25.0        24                               merlu
# 28        29        26.0        24                             julnosk
# 29        30        28.0        24                            alina818
# 30        31        29.0        25                  viktoriamoskalenko
#
#     obs_count obs_count_shift  obs_res_count obs_res_count_shift    last_obs
# 0         278            +277            194                +193  2023-02-19
# 1         222                            161                      2023-02-14
# 2          93                             90                      2021-08-07
# 3          62                             56                      2021-08-31
# 4          41                             38                      2022-07-16
# 5          37                             37                      2020-09-05
# 6          37                             26                      2021-11-04
# 7          30                             23                      2019-06-22
# 8          24                             24                      2021-07-19
# 9          14                             13                      2022-07-20
# 10         14                              4                      2022-06-18
# 11         11                             11                      2020-06-14
# 12          8                              6                      2022-10-17
# 13          7              +5              7                  +5  2022-09-13
# 14          7                              6                      2020-07-31
# 15          7                              4                      2019-08-01
# 16          6                              5                      2019-06-03
# 17          5                              4                      2019-07-12
# 18          4                              4                      2020-05-15
# 19          3                              3                      2022-06-06
# 20          3                              2                      2021-06-14
# 21          2                              2                      2019-06-06
# 22          2                              2                      2020-06-11
# 23          2                              0                      2018-09-24
# 24          1                              1                      2021-11-07
# 25          1                              1                      2020-05-22
# 26          1                              1                      2019-05-28
# 27          1                              1                      2022-02-24
# 28          1                              1                      2022-07-05
# 29          1                              1                      2020-06-10
# 30          1                              0                      2020-09-06

# %%
changes_linked = changes.apply(changes_linking, axis=1)
changes_linked
# Out:
#     position  position_y  pos_cool pos_cool_shift  \
# 0          1        27.0         1            +19
# 1          2         0.0         2           +new
# 2          3         1.0         3
# 3          4         2.0         4
# 4          5         3.0         5
# 5          6         4.0         6
# 6          7         5.0         7
# 7          8         6.0         8
# 8          9         7.0         9
# 9         10         8.0        10
# 10        11         9.0        11
# 11        12        10.0        12
# 12        13         0.0        13           +new
# 13        14        19.0        14             +4
# 14        15        11.0        15
# 15        16        12.0        16
# 16        17        13.0        17
# 17        18        14.0        18
# 18        19        15.0        19
# 19        20        16.0        20
# 20        21        17.0        21
# 21        22        18.0        22
# 22        23        20.0        22
# 23        24        21.0        23
# 24        25        22.0        24
# 25        26        23.0        24
# 26        27        24.0        24
# 27        28        25.0        24
# 28        29        26.0        24
# 29        30        28.0        24
# 30        31        29.0        25
#
#                                               user  \
# 0         <span color:black">@budetinetakoe</span>
# 1   <span color:black">@anastasiiamerkulova</span>
# 2          <span color:black">@elenasuslova</span>
# 3      <span color:black">@mitrula_paludosa</span>
# 4        <span color:black">@daria_kalinina</span>
# 5                <span color:black">@taimyr</span>
# 6        <span color:black">@kirill_kuptsov</span>
# 7              <span color:black">@bio_4you</span>
# 8   <span color:black">@elizaveta_boldinova</span>
# 9       <span color:black">@naturalist40722</span>
# 10                <span color:black">@wuce6</span>
# 11                <span color:black">@lande</span>
# 12        <span color:black">@infifororient</span>
# 13             <span color:black">@forestru</span>
# 14         <span color:black">@yu_postnikov</span>
# 15            <span color:black">@lachinova</span>
# 16               <span color:black">@irened</span>
# 17         <span color:black">@ivan_savinov</span>
# 18              <span color:black">@elfenok</span>
# 19            <span color:black">@anatoly_m</span>
# 20          <span color:black">@oxanasayuri</span>
# 21      <span color:black">@naturalist14616</span>
# 15  <a href="https://www.inaturalist.org/observati...  2019-08-01
# 16  <a href="https://www.inaturalist.org/observati...  2019-06-03
# 17  <a href="https://www.inaturalist.org/observati...  2019-07-12
# 18  <a href="https://www.inaturalist.org/observati...  2020-05-15
# 19  <a href="https://www.inaturalist.org/observati...  2022-06-06
# 20  <a href="https://www.inaturalist.org/observati...  2021-06-14
# 21  <a href="https://www.inaturalist.org/observati...  2019-06-06
# 22  <a href="https://www.inaturalist.org/observati...  2020-06-11
# 23  <a href="https://www.inaturalist.org/observati...  2018-09-24
# 24  <a href="https://www.inaturalist.org/observati...  2021-11-07
# 25  <a href="https://www.inaturalist.org/observati...  2020-05-22
# 26  <a href="https://www.inaturalist.org/observati...  2019-05-28
# 27  <a href="https://www.inaturalist.org/observati...  2022-02-24
# 28  <a href="https://www.inaturalist.org/observati...  2022-07-05
# 29  <a href="https://www.inaturalist.org/observati...  2020-06-10
# 30  <a href="https://www.inaturalist.org/observati...  2020-09-06

# %%
changes = changes_beauty(changes_linked, show_positions)
changes
# Out:
#          #                                             Кто  \
# 0     1+19        <span color:black">@budetinetakoe</span>
# 1    2+new  <span color:black">@anastasiiamerkulova</span>
# 2        3         <span color:black">@elenasuslova</span>
# 3        4     <span color:black">@mitrula_paludosa</span>
# 4        5       <span color:black">@daria_kalinina</span>
# 5        6               <span color:black">@taimyr</span>
# 6        7       <span color:black">@kirill_kuptsov</span>
# 7        8             <span color:black">@bio_4you</span>
# 8        9  <span color:black">@elizaveta_boldinova</span>
# 9       10      <span color:black">@naturalist40722</span>
# 10      11                <span color:black">@wuce6</span>
# 11      12                <span color:black">@lande</span>
# 12  13+new        <span color:black">@infifororient</span>
# 13    14+4             <span color:black">@forestru</span>
# 14      15         <span color:black">@yu_postnikov</span>
# 15      16            <span color:black">@lachinova</span>
# 16      17               <span color:black">@irened</span>
# 17      18         <span color:black">@ivan_savinov</span>
# 18      19              <span color:black">@elfenok</span>
# 19      20            <span color:black">@anatoly_m</span>
# 20      21          <span color:black">@oxanasayuri</span>
# 21      22      <span color:black">@naturalist14616</span>
# 22      22              <span color:black">@datakuz</span>
# 23      23            <span color:black">@entomokot</span>
# 24      24      <span color:black">@naturalist35009</span>
# 25      24      <span color:black">@naturalist33527</span>
# 26      24      <span color:black">@naturalist11373</span>
# 27      24                <span color:black">@merlu</span>
# 28      24              <span color:black">@julnosk</span>
# 29      24             <span color:black">@alina818</span>
# 30      25   <span color:black">@viktoriamoskalenko</span>
#
#                                            Наблюдения  \
# 0   <a href="https://www.inaturalist.org/observati...
# 1   <a href="https://www.inaturalist.org/observati...
# 2   <a href="https://www.inaturalist.org/observati...
# 3   <a href="https://www.inaturalist.org/observati...
# 4   <a href="https://www.inaturalist.org/observati...
# 5   <a href="https://www.inaturalist.org/observati...
# 6   <a href="https://www.inaturalist.org/observati...
# 7   <a href="https://www.inaturalist.org/observati...
# 8   <a href="https://www.inaturalist.org/observati...
